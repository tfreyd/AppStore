# %% [markdown]
# ## ads engagement and app's type 2018
# - identified the kind of free app the users of the different os are into, are they a general trend?
# - no info about the ads category
#
# - find free app
# - what category with the highest grade

# %%
from csv import reader
ios=open('./AppleStore.csv')
ios=reader(ios)
ios=list(ios)
google=open('googleplaystore.csv')
google=reader(google)
google=list(google)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-962eb3a652c5> in <module>()
#       1 from csv import reader
# ----> 2 ios=open('./AppleStore.csv')
#       3 ios=reader(ios)
#       4 ios=list(ios)
#       5 google=open('googleplaystore.csv')
#
# FileNotFoundError: [Errno 2] No such file or directory: './AppleStore.csv'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def explore_data(dataset, start, end, rows_and_columns=False):
    dataset_slice = dataset[start:end]    
    for row in dataset_slice:
        print(row)
        print('\n') # adds a new (empty) line after each row

    if rows_and_columns:
        print('Number of rows:', len(dataset))
        print('Number of columns:', len(dataset[0]))

google[0]
# Out:
# ['App',
#  'Category',
#  'Rating',
#  'Reviews',
#  'Size',
#  'Installs',
#  'Type',
#  'Price',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
#detection of an issue at index 10473 of google data set
del google[10473]
for row in google:
    if len(row) != len(google[0]):
        print(row)
        print(google.index(row))

# %%
#detection issue ios data set
for row in ios:
    if len(row) != len(ios[0]):
        print(row)
        print(ios.index(row))

# %%
#detection of duplicate apps in Apple Store data set method 1
ios_app_names={} #creation of a dictionnary
ios_app_names_duplicate=[]
for row in ios:
    name=row[1]
    if name in ios_app_names: #counting for each app name
        ios_app_names[name] +=1
    else:
        ios_app_names[name]=1
#detection of app found more than once 
for name in ios_app_names:
    if ios_app_names[name] !=1:
        ios_app_names_duplicate.append(name) #the creation of the list is not necessary
        print(name, ios_app_names[name])
# Out:
# Mannequin Challenge 2
# VR Roller Coaster 2

# %% [markdown]
# - 2 duplicate apps were detected in the iOS data set
# - screen through the data set to keep unique and in case of duplicate apps keep the one with the highest rating count

# %%
#find duplicates in the ios DataSet and 
#keep the one with the highest number of ratings
reviews_max={}
for row in ios[1:]:
    name=row[1]
    n_reviews=row[5]
    if name not in reviews_max :
        reviews_max[name]=n_reviews
    if name in reviews_max and reviews_max[name] < n_reviews:
        reviews_max[name]=n_reviews
len(reviews_max)

ios_clean=[]
ios_already_added=[]
for row in ios[1:]:
    name=row[1]
    n_reviews=row[5]
    if  n_reviews==reviews_max[name] and name not in ios_already_added:
        ios_clean.append(row)
        ios_already_added.append(name)


len(ios_clean)
# Out:
# 7195

# %%
#same than cell above but applied on the google store data set 
reviews_max={}

for row in google[1:]:
    name=row[0]
    n_reviews=float(row[3])
    
    if name in reviews_max and reviews_max[name] < n_reviews:
        reviews_max[name]=n_reviews
        
    elif name not in reviews_max :
        reviews_max[name]=n_reviews
        
print(len(reviews_max))

#
google_clean = []
google_already_added = []

for row in google[1:]:
    name=row[0]
    n_reviews=float(row[3])
    if name not in google_already_added and n_reviews==reviews_max[name]:
        google_clean.append(row)
        google_already_added.append(name)

print(len(google_clean))
print(len(google_already_added))
# Out:
# 9659
# 9659
# 9659

# %% [markdown]
# #### function to detect if function english

# %%
#function to see if english app by checking if ASCII code >127 
#def english(name):
#   
#    for character in name:
#        if ord(character)>127:
#           return False
 #  return True

# %%
#english('Docs To Go™ Free Office Suite')

# %% [markdown]
# the "english" function does not handle well when there are unsual characters or slimeys. the function will hence be less sensitive and 3

# %%
def english(name):
    aberation=0
    
    for character in name:      
        if ord(character)>127:
            aberation += 1
            
    if aberation>3:
        return False                    
    return True

def is_english(string):
    non_ascii = 0
    
    for character in string:
        if ord(character) > 127:
            non_ascii += 1
    
    if non_ascii > 3:
        return False
    else:
        return True

print(is_english('Docs To Go™ Free Office Suite'))
print(is_english('Instachat 😜'))
# Out:
# True
# True

# %%
english('爱奇艺PPS -《欢乐颂2》电视剧热播')
# Out:
# False

# %%
ios_english_apps=[]
google_english_apps=[]

for row in google_clean:
    name=row[0]
    if english(name):
        google_english_apps.append(row)
print(len(google_english_apps))

for row in ios_clean:
    name=row[1]
    if english(name):
        ios_english_apps.append(row)
print(len(ios_english_apps))
# Out:
# 9614
# 6181

# %% [markdown]
# ### isolation of free apps

# %%
#ios free app
ios_headers=ios[0]
ios_final=[]
for row in ios_english_apps:
    price=row[4]
    if price=='0.0':
        ios_final.append(row)    
len(ios_final)
# Out:
# 3220

# %%
#google Play store free app
google_headers=google[0]
google_final=[]
for row in google_english_apps:
    rating=row[7]
    if rating==str(0):
        google_final.append(row)
len(google_final)
# Out:
# 8864

# %% [markdown]
# ### identification of the differents genres

# %%
google[0:2]
# Out:
# [['App',
#   'Category',
#   'Rating',
#   'Reviews',
#   'Size',
#   'Installs',
#   'Type',
#   'Price',
#   'Content Rating',
#   'Genres',
#   'Last Updated',
#   'Current Ver',
#   'Android Ver'],
#  ['Photo Editor & Candy Camera & Grid & ScrapBook',
#   'ART_AND_DESIGN',
#   '4.1',
#   '159',
#   '19M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'January 7, 2018',
#   '1.0.0',
#   '4.0.3 and up']]

# %% [markdown]
# - for google_final dataset we can use the column 9 corresponding to the Type of applicaiton to set up a dictionnary and a counting to know the common genres on the respective markets

# %%
google_genres={}
for row in google_final:
    genre=row[9]
    if genre in google_genres:
        google_genres[genre] +=1
    else:
        google_genres[genre] = 1
total_app=len(google_final)

for genre in google_genres:
    google_genres[genre] = (google_genres[genre]%total_app)
    print(google_genres)
# Out:
# {'Art & Design': 53, 'Art & Design;Creativity': 6, 'Auto & Vehicles': 82, 'Beauty': 53, 'Books & Reference': 190, 'Business': 407, 'Comics': 54, 'Comics;Creativity': 1, 'Communication': 287, 'Dating': 165, 'Education': 474, 'Education;Creativity': 4, 'Education;Education': 30, 'Education;Pretend Play': 5, 'Education;Brain Games': 3, 'Entertainment': 538, 'Entertainment;Brain Games': 7, 'Entertainment;Creativity': 3, 'Entertainment;Music & Video': 15, 'Events': 63, 'Finance': 328, 'Food & Drink': 110, 'Health & Fitness': 273, 'House & Home': 73, 'Libraries & Demo': 83, 'Lifestyle': 345, 'Lifestyle;Pretend Play': 1, 'Card': 40, 'Arcade': 164, 'Puzzle': 100, 'Racing': 88, 'Sports': 307, 'Casual': 156, 'Simulation': 181, 'Adventure': 60, 'Trivia': 37, 'Action': 275, 'Word': 23, 'Role Playing': 83, 'Strategy': 81, 'Board': 34, 'Music': 18, 'Action;Action & Adventure': 9, 'Casual;Brain Games': 12, 'Educational;Creativity': 3, 'Puzzle;Brain Games': 15, 'Educational;Education': 35, 'Casual;P
# ...

# %%
google_genres
# Out:
# {'Art & Design': 53,
#  'Art & Design;Creativity': 6,
#  'Auto & Vehicles': 82,
#  'Beauty': 53,
#  'Books & Reference': 190,
#  'Business': 407,
#  'Comics': 54,
#  'Comics;Creativity': 1,
#  'Communication': 287,
#  'Dating': 165,
#  'Education': 474,
#  'Education;Creativity': 4,
#  'Education;Education': 30,
#  'Education;Pretend Play': 5,
#  'Education;Brain Games': 3,
#  'Entertainment': 538,
#  'Entertainment;Brain Games': 7,
#  'Entertainment;Creativity': 3,
#  'Entertainment;Music & Video': 15,
#  'Events': 63,
#  'Finance': 328,
#  'Food & Drink': 110,
#  'Health & Fitness': 273,
#  'House & Home': 73,
#  'Libraries & Demo': 83,
#  'Lifestyle': 345,
#  'Lifestyle;Pretend Play': 1,
#  'Card': 40,
#  'Arcade': 164,
#  'Puzzle': 100,
#  'Racing': 88,
#  'Sports': 307,
#  'Casual': 156,
#  'Simulation': 181,
#  'Adventure': 60,
#  'Trivia': 37,
#  'Action': 275,
#  'Word': 23,
#  'Role Playing': 83,
#  'Strategy': 81,
#  'Board': 34,
#  'Music': 18,
# ...

# %%
ios_genres={}
for row in ios_final:
    genre=row[11]
    if genre in ios_genres:
        ios_genres[genre] += 1
    else:
        ios_genres[genre]=1

# %%
ios_genres
# Out:
# {'Social Networking': 106,
#  'Photo & Video': 160,
#  'Games': 1872,
#  'Music': 66,
#  'Reference': 18,
#  'Health & Fitness': 65,
#  'Weather': 28,
#  'Utilities': 81,
#  'Travel': 40,
#  'Shopping': 84,
#  'News': 43,
#  'Navigation': 6,
#  'Lifestyle': 51,
#  'Entertainment': 254,
#  'Food & Drink': 26,
#  'Sports': 69,
#  'Book': 14,
#  'Finance': 36,
#  'Education': 118,
#  'Productivity': 56,
#  'Business': 17,
#  'Catalogs': 4,
#  'Medical': 6}

# %%
def freq_table(dataset, index):
    #building of the dictionnary
    content_column={}
       
    for row in dataset:
        string=row[index]
        if string in content_column:
            content_column[string] += 1
        else:
            content_column[string] = 1
#buiding of the frequencies table                
    total=len(dataset)
    freq_table={}
    
    for string in content_column:
        freq_table[string]= content_column[string]/total *100
    return freq_table

#in order to sort the frequencies table in reverse order
def display_table(dataset, index):
    table = freq_table(dataset, index)
    table_display = []
    for key in table:
        key_val_as_tuple = (table[key], key)
        table_display.append(key_val_as_tuple)

    table_sorted = sorted(table_display, reverse = True)
    for entry in table_sorted:
        print(entry[1], ':', entry[0])

# %%
display_table(ios_final, 11)
# Out:
# Games : 58.13664596273293
# Entertainment : 7.888198757763975
# Photo & Video : 4.968944099378882
# Education : 3.6645962732919255
# Social Networking : 3.291925465838509
# Shopping : 2.608695652173913
# Utilities : 2.515527950310559
# Sports : 2.142857142857143
# Music : 2.049689440993789
# Health & Fitness : 2.018633540372671
# Productivity : 1.7391304347826086
# Lifestyle : 1.5838509316770186
# News : 1.3354037267080745
# Travel : 1.2422360248447204
# Finance : 1.1180124223602486
# Weather : 0.8695652173913043
# Food & Drink : 0.8074534161490683
# Reference : 0.5590062111801243
# Business : 0.5279503105590062
# Book : 0.43478260869565216
# Navigation : 0.18633540372670807
# Medical : 0.18633540372670807
# Catalogs : 0.12422360248447205

# %%
display_table(google_final,1)
# Out:
# FAMILY : 18.907942238267147
# GAME : 9.724729241877256
# TOOLS : 8.461191335740072
# BUSINESS : 4.591606498194946
# LIFESTYLE : 3.9034296028880866
# PRODUCTIVITY : 3.892148014440433
# FINANCE : 3.7003610108303246
# MEDICAL : 3.531137184115524
# SPORTS : 3.395758122743682
# PERSONALIZATION : 3.3167870036101084
# COMMUNICATION : 3.2378158844765346
# HEALTH_AND_FITNESS : 3.0798736462093865
# PHOTOGRAPHY : 2.944494584837545
# NEWS_AND_MAGAZINES : 2.7978339350180503
# SOCIAL : 2.6624548736462095
# TRAVEL_AND_LOCAL : 2.33528880866426
# SHOPPING : 2.2450361010830324
# BOOKS_AND_REFERENCE : 2.1435018050541514
# DATING : 1.861462093862816
# VIDEO_PLAYERS : 1.7937725631768955
# MAPS_AND_NAVIGATION : 1.3989169675090252
# FOOD_AND_DRINK : 1.2409747292418771
# EDUCATION : 1.1620036101083033
# ENTERTAINMENT : 0.9589350180505415
# LIBRARIES_AND_DEMO : 0.9363718411552346
# AUTO_AND_VEHICLES : 0.9250902527075812
# HOUSE_AND_HOME : 0.8235559566787004
# WEATHER : 0.8009927797833934
# ...

# %%
display_table(google_final,9)
# Out:
# Tools : 8.449909747292418
# Entertainment : 6.069494584837545
# Education : 5.347472924187725
# Business : 4.591606498194946
# Productivity : 3.892148014440433
# Lifestyle : 3.892148014440433
# Finance : 3.7003610108303246
# Medical : 3.531137184115524
# Sports : 3.463447653429603
# Personalization : 3.3167870036101084
# Communication : 3.2378158844765346
# Action : 3.1024368231046933
# Health & Fitness : 3.0798736462093865
# Photography : 2.944494584837545
# News & Magazines : 2.7978339350180503
# Social : 2.6624548736462095
# Travel & Local : 2.3240072202166067
# Shopping : 2.2450361010830324
# Books & Reference : 2.1435018050541514
# Simulation : 2.0419675090252705
# Dating : 1.861462093862816
# Arcade : 1.8501805054151623
# Video Players & Editors : 1.7712093862815883
# Casual : 1.7599277978339352
# Maps & Navigation : 1.3989169675090252
# Food & Drink : 1.2409747292418771
# Puzzle : 1.128158844765343
# Racing : 0.9927797833935018
# Role Playing : 0.9363718411552346
# ...

# %%
#examin deeper the family category in the google play store
google_family=[]

for line in google_final:
    genre=line[1]
    if str(genre) == 'FAMILY':
        google_family.append(line)

# %%
display_table(google_family, 9)
# Out:
# Entertainment : 27.326968973747018
# Education : 22.79236276849642
# Simulation : 10.381861575178998
# Casual : 7.995226730310262
# Puzzle : 4.6539379474940334
# Role Playing : 4.295942720763723
# Strategy : 3.9379474940334127
# Educational;Education : 2.088305489260143
# Educational : 1.9689737470167064
# Education;Education : 1.431980906921241
# Casual;Pretend Play : 1.2529832935560858
# Racing;Action & Adventure : 0.8949880668257757
# Puzzle;Brain Games : 0.8949880668257757
# Entertainment;Music & Video : 0.7159904534606205
# Casual;Action & Adventure : 0.7159904534606205
# Casual;Brain Games : 0.6563245823389021
# Arcade;Action & Adventure : 0.6563245823389021
# Educational;Pretend Play : 0.47732696897374705
# Action;Action & Adventure : 0.47732696897374705
# Simulation;Action & Adventure : 0.41766109785202865
# Board;Brain Games : 0.41766109785202865
# Entertainment;Brain Games : 0.35799522673031026
# Educational;Brain Games : 0.35799522673031026
# ...

# %% [markdown]
# ## analyse of average number of users per category to detecte the genre the most popular not the most populated as we did previously
# we start with ios and the number of installation by category ios[0][5]

# %%
ios[0][5]
# Out:
# 'rating_count_tot'

# %%
#frequency table of prime_genre in iOS 
#and the average number of users per genre
popular_genre={}
most_popular=0
max_avg_users=0
for genre in freq_table(ios_final,11): #return the frequence table of the index in the dataset
    total=0
    len_genre=0
   
    
    for row in ios_final:
        genre_app=row[11]
        if genre_app == genre:
            n_user=int(row[5])
            total += n_user
            len_genre += 1
    avg_users=total/len_genre
    popular_genre[genre]=avg_users
    if avg_users > max_avg_users:
        max_avg_users=avg_users
        most_popular=genre
    
    print(int(total/len_genre)," average users", ' for', genre)
     
print('The most popular genre in iOS is ',most_popular,' with ',int(max_avg_users)," users")
# Out:
# 71548  average users  for Social Networking
# 28441  average users  for Photo & Video
# 22812  average users  for Games
# 57326  average users  for Music
# 74942  average users  for Reference
# 23298  average users  for Health & Fitness
# 52279  average users  for Weather
# 18684  average users  for Utilities
# 28243  average users  for Travel
# 26919  average users  for Shopping
# 21248  average users  for News
# 86090  average users  for Navigation
# 16485  average users  for Lifestyle
# 14029  average users  for Entertainment
# 33333  average users  for Food & Drink
# 23008  average users  for Sports
# 39758  average users  for Book
# 31467  average users  for Finance
# 7003  average users  for Education
# 21028  average users  for Productivity
# 7491  average users  for Business
# 4004  average users  for Catalogs
# 612  average users  for Medical
# The most popular genre in iOS is  Navigation  with  86090  users

# %% [markdown]
# ## most popular genres in Android
# appreciation of popularity of a genre by the average number of installation per app genre
# install info google[0][5]

# %%
google_cat=freq_table(google_final, 1)
google_cat
# Out:
# {'ART_AND_DESIGN': 0.6430505415162455,
#  'AUTO_AND_VEHICLES': 0.9250902527075812,
#  'BEAUTY': 0.5979241877256317,
#  'BOOKS_AND_REFERENCE': 2.1435018050541514,
#  'BUSINESS': 4.591606498194946,
#  'COMICS': 0.6204873646209386,
#  'COMMUNICATION': 3.2378158844765346,
#  'DATING': 1.861462093862816,
#  'EDUCATION': 1.1620036101083033,
#  'ENTERTAINMENT': 0.9589350180505415,
#  'EVENTS': 0.7107400722021661,
#  'FINANCE': 3.7003610108303246,
#  'FOOD_AND_DRINK': 1.2409747292418771,
#  'HEALTH_AND_FITNESS': 3.0798736462093865,
#  'HOUSE_AND_HOME': 0.8235559566787004,
#  'LIBRARIES_AND_DEMO': 0.9363718411552346,
#  'LIFESTYLE': 3.9034296028880866,
#  'GAME': 9.724729241877256,
#  'FAMILY': 18.907942238267147,
#  'MEDICAL': 3.531137184115524,
#  'SOCIAL': 2.6624548736462095,
#  'SHOPPING': 2.2450361010830324,
#  'PHOTOGRAPHY': 2.944494584837545,
#  'SPORTS': 3.395758122743682,
#  'TRAVEL_AND_LOCAL': 2.33528880866426,
#  'TOOLS': 8.461191335740072,
# ...

# %%
for category in google_cat:
    total=0
    len_category=0
    
    for row in google_final:
        category_app=row[1]
        
        if category_app == category:       
            n_installs=row[5]
            n_installs=n_installs.replace('+','')
            n_installs=n_installs.replace(',','')
            print(n_installs)
            n_installs=float(n_installs)
            total+=n_installs
            len_category +=1
    print(cat)        
    print(total)
# Out:
# 10000
# 5000000
# 50000000
# 100000
# 50000
# 50000
# 1000000
# 1000000
# 10000
# 1000000
# 1000000
# 10000000
# 100000
# 100000
# 5000
# 500000
# 10000
# 5000000
# 10000000
# 100000
# 100000
# 500000
# 50000
# 10000
# 500000
# 100000
# 10000
# 100000
# 100000
# 50000
# 100000
# 100000
# 10000
# 100000
# 5000000
# 10000
# 500000
# 10000
# 100000
# 100000
# 10000
# 10000000
# 100000
# 100000
# 100000
# 50000
# 10000000
# 100000
# 100000
# 5000
# 1000
# 5000
# 5000
# 50000
# 10000
# 0
# 100
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-024a09e19a7e> in <module>
#      14             total+=n_installs
#      15             len_category +=1
# ---> 16     print(cat)
#      17     print(total)
#
# NameError: name 'cat' is not defined
